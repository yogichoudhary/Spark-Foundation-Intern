# %% [markdown]
# # Yogendra Task 1(Prediction using Supervised ML)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# %%
url="http://bit.ly/w-data"
df=pd.read_csv(url)
print("The data is imported successfully")
df
# Out:
# The data is imported successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df=df.values
x=df[:,0]
x=np.float32(x)
x = np.array([x]).reshape((-1, 1))
y=df[:,1]
y=np.float32(y)

# %%
plt.figure(figsize=(8,6))
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                            test_size=0.1, random_state=1)
print(x_test,'\n',y_test)
plt.scatter(x,y)
plt.show()
# Out:
# [[1.1]
#  [3.3]
#  [1.9]]
#  [17. 42. 24.]

# %% [markdown]
# # Creating and Training the Model

# %%
plt.figure(figsize=(18,12))
model = LinearRegression()
model.fit(x_train, y_train)
coeff=model.coef_
intercept=model.intercept_
linear_regression_line= intercept + coeff*x
plt.scatter(x,y)
plt.plot(x,linear_regression_line)
plt.show()

# %%
y_predicted = model.predict(x_test)
y_predicted
# Out:
# array([11.120119, 33.383686, 19.215961], dtype=float32)

# %% [markdown]
# # Testing the Model

# %%
Error = np.mean(abs(y_test - y_predicted))
print('Absolute Mean Error in prediction: ', Error)
# Out:
# Absolute Mean Error in prediction:  6.4267445

# %%
#testing for hours=9.25
custom_input=9.25
hours=np.array([custom_input]).reshape((-1,1))
y_pred=model.predict(hours)
print(f"The predicted marks after studying for {custom_input}hrs a day: ", y_pred)
# Out:
# The predicted marks after studying for 9.25hrs a day:  [93.59651637]
